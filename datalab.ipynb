# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the Data

# %%
world_cup = pd.read_csv("WorldCupMatches.csv")
world_cup.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
world_cup.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# ...

# %%
world_cup.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# ...

# %%
world_cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
# ...

# %%
turple = world_cup.shape
turple
# Out:
# (852, 20)

# %%
type(world_cup.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
world_cup.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting DataFrame Information

# %%
# display all the information from the 3rd to the 5th game
world_cup.iloc[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# ...

# %%
world_cup.iloc[:, 5:9]
# Out:
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name
# 0           France                4                1         Mexico
# 1              USA                3                0        Belgium
# 2       Yugoslavia                2                1         Brazil
# 3          Romania                3                1           Peru
# 4        Argentina                1                0         France
# ..             ...              ...              ...            ...
# 847    Netherlands                0                0     Costa Rica
# 848         Brazil                1                7        Germany
# 849    Netherlands                0                0      Argentina
# 850         Brazil                0                3    Netherlands
# 851        Germany                1                0      Argentina
#
# [852 rows x 4 columns]

# %%
world_cup[world_cup["Year"] == 1950]
# Out:
#     Year              Datetime    Stage  \
# 53  1950  24 Jun 1950 - 15:00   Group 1
# 54  1950  25 Jun 1950 - 15:00   Group 2
# 55  1950  25 Jun 1950 - 15:00   Group 2
# 56  1950  25 Jun 1950 - 15:00   Group 3
# 57  1950  25 Jun 1950 - 15:00   Group 1
# 58  1950  28 Jun 1950 - 15:00   Group 1
# 59  1950  28 Jun 1950 - 15:00   Group 1
# 60  1950  29 Jun 1950 - 15:00   Group 2
# 61  1950  29 Jun 1950 - 15:30   Group 3
# 62  1950  29 Jun 1950 - 15:00   Group 2
# 63  1950  01 Jul 1950 - 15:00   Group 1
# 64  1950  02 Jul 1950 - 15:00   Group 2
# 65  1950  02 Jul 1950 - 15:00   Group 3
# 66  1950  02 Jul 1950 - 15:00   Group 4
# 67  1950  02 Jul 1950 - 15:40   Group 1
# 68  1950  02 Jul 1950 - 15:00   Group 2
# 69  1950  09 Jul 1950 - 15:00   Group 6
# 70  1950  09 Jul 1950 - 15:00   Group 6
# 71  1950  13 Jul 1950 - 15:00   Group 6
# 72  1950  13 Jul 1950 - 15:00   Group 6
# 73  1950  16 Jul 1950 - 15:00   Group 6
# 74  1950  16 Jul 1950 - 15:00   Group 6
#
# ...

# %%
group3_wc50 = world_cup[(world_cup["Year"] == 1950) & (world_cup["Stage"] == "Group 3")]
group3_wc50
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# ...

# %%
gr3_y50 = world_cup[(world_cup["Year"] == 1950) & (world_cup["Stage"] == "Group 3")]["Attendance"]
gr3_y50
# Out:
# 56    36502.0
# 61     7903.0
# 65    25811.0
# Name: Attendance, dtype: float64

# %%
# how many home games were played by the Netherlands?
ned_home = world_cup[world_cup["Home Team Name"] == "Netherlands"]
ned_home.head()
# Out:
#      Year               Datetime    Stage           Stadium            City  \
# 244  1974   19 Jun 1974 - 19:30   Group 3  Westfalenstadion       Dortmund
# 258  1974   26 Jun 1974 - 19:30   Group A       Parkstadion  Gelsenkirchen
# 265  1974   03 Jul 1974 - 19:30   Group A  Westfalenstadion       Dortmund
# 269  1974  07 July 1974 - 16:00     Final    Olympiastadion         Munich
# 277  1978   03 Jun 1978 - 16:45   Group 4        San Martin        Mendoza
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 244    Netherlands                0                0         Sweden
# 258    Netherlands                4                0      Argentina
# 265    Netherlands                2                0         Brazil
# 269    Netherlands                1                2     Germany FR
# 277    Netherlands                3                0        IR Iran
#
#     Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# ...

# %%
row_count = len(ned_home)
row_count
# Out:
# 32

# %%
ned_away = world_cup[world_cup["Away Team Name"] == "Netherlands"]
ned_away.head()
# Out:
#      Year              Datetime              Stage               Stadium  \
# 20   1934  27 May 1934 - 16:30   Preliminary round              San Siro
# 41   1938  05 Jun 1938 - 18:30         First round           Cavee Verte
# 236  1974  15 Jun 1974 - 16:00             Group 3  Niedersachsenstadion
# 252  1974  23 Jun 1974 - 16:00             Group 3      Westfalenstadion
# 262  1974  30 Jun 1974 - 16:00             Group A           Parkstadion
#
#                City  Home Team Name  Home Team Goals  Away Team Goals  \
# 20           Milan      Switzerland                3                2
# 41        Le Havre   Czechoslovakia                3                0
# 236        Hanover          Uruguay                0                2
# 252       Dortmund         Bulgaria                1                4
# 262  Gelsenkirchen        German DR                0                2
#
#     Away Team Name                        Win conditions  Attendance  \
# ...

# %%
# How many games were played by the Netherlands in total?
total_ned = len(ned_away) + len(ned_home)
total_ned
# Out:
# 54

# %%
# games the USA played in the 2014 World Cup.
usa_home = world_cup[(world_cup["Year"] == 2014) & (world_cup["Home Team Name"] == "USA")]
home_rows = len(usa_home)


usa_away = world_cup[(world_cup["Year"] == 2014) & (world_cup["Away Team Name"] == "USA")]
away_rows = len(usa_away)

home_rows + away_rows
# Out:
# 5

# %%
home_teams = world_cup["Home Team Name"]
type(home_teams)
# Out:
# pandas.core.series.Series

# %%
away_teams = world_cup["Away Team Name"]
type(away_teams)
# Out:
# pandas.core.series.Series

# %%
home_list = list(home_teams)

# %%
away_list = list(away_teams)

# %%
total_teams = (away_list) and (home_list)

# %%
teams = len(set(total_teams))

# %%
print(f"A total of {teams} have participated in the World Cup since inception")
# Out:
# A total of 78 have participated in the World Cup since inception

# %%
# how many countries participated in the 1986 World Cup
wc1986 = world_cup[world_cup["Year"] == 1986]
wc1986.head()
# Out:
#      Year              Datetime    Stage                         Stadium  \
# 360  1986  31 May 1986 - 12:00   Group A                  Estadio Azteca
# 361  1986  01 Jun 1986 - 16:00   Group C         Nou Camp - Estadio Le�n
# 362  1986  01 Jun 1986 - 12:00   Group D                         Jalisco
# 363  1986  02 Jun 1986 - 12:00   Group C                Estadio Irapuato
# 364  1986  02 Jun 1986 - 12:00   Group A  Estadio Ol�mpico Universitario
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# 360  Mexico City        Bulgaria                1                1
# 361         Leon          Canada                0                1
# 362  Guadalajara           Spain                0                1
# 363     Irapuato    Soviet Union                6                0
# 364  Mexico City       Argentina                3                1
#
#      Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# ...

# %%
teams_1986 = set(list(wc1986["Home Team Name"]) and list(wc1986["Away Team Name"]))
total_1986 = len(teams_1986)
print(f"A total of {total_1986} participated in the 1986 World Cup since inception")
# Out:
# A total of 24 participated in the 1986 World Cup since inception

# %% [markdown]
# ### Changing Values and Creating New Columns

# %%
# how many matches had 5 goals or more in total
world_cup["Total Goals"] = world_cup["Home Team Goals"] + world_cup["Away Team Goals"] 
above5_goals = world_cup[world_cup["Total Goals"] >= 5]
matches = len(above5_goals)
matches
# Out:
# 147

# %%
world_cup.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
world_cup["Half Time Goals"] = world_cup["Half-time Home Goals"] + world_cup["Half-time Away Goals"]
world_cup.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  ...  Half-time Away Goals                 Referee  \
# 0                 ...                     0  LOMBARDI Domingo (URU)
# ...

# %%
world_cup.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Half Time Goals'],
#       dtype='object')

# %%
world_cup.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
# Run this cell without changes

# Display all records containing the string 'Korea'

world_cup.loc[world_cup['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %%
world_cup.loc[world_cup['Home Team Name'].str.contains('Korea'), 'Home Team Name'] = "Korea"

# %%
world_cup.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
world_cup.loc[world_cup['Away Team Name'].str.contains('Korea'), 'Away Team Name']
# Out:
# 80     Korea Republic
# 88     Korea Republic
# 171         Korea DPR
# 195         Korea DPR
# 364    Korea Republic
# 421    Korea Republic
# 464    Korea Republic
# 490    Korea Republic
# 542    Korea Republic
# 556    Korea Republic
# 625    Korea Republic
# 639    Korea Republic
# 640    Korea Republic
# 672    Korea Republic
# 691    Korea Republic
# 721         Korea DPR
# 725    Korea Republic
# 737         Korea DPR
# 742    Korea Republic
# 756    Korea Republic
# 788    Korea Republic
# Name: Away Team Name, dtype: object

# %%
world_cup.loc[world_cup['Away Team Name'].str.contains('Korea'), 'Away Team Name'] = "Korea"

# %%
world_cup.loc[world_cup['Away Team Name'].str.contains('Korea'), 'Away Team Name']
# Out:
# 80     Korea
# 88     Korea
# 171    Korea
# 195    Korea
# 364    Korea
# 421    Korea
# 464    Korea
# 490    Korea
# 542    Korea
# 556    Korea
# 625    Korea
# 639    Korea
# 640    Korea
# 672    Korea
# 691    Korea
# 721    Korea
# 725    Korea
# 737    Korea
# 742    Korea
# 756    Korea
# 788    Korea
# Name: Away Team Name, dtype: object

# %%
world_cup.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Half Time Goals'],
#       dtype='object')

# %%
world_cup.loc[world_cup['Home Team Initials'].isin(['PRK', 'KOR']), 'Home Team Initials']
# Out:
# 179    PRK
# 187    PRK
# 374    KOR
# 386    KOR
# 434    KOR
# 444    KOR
# 480    KOR
# 524    KOR
# 593    KOR
# 609    KOR
# 635    KOR
# 642    KOR
# 655    KOR
# 710    KOR
# 753    PRK
# 802    KOR
# 818    KOR
# Name: Home Team Initials, dtype: object

# %%
# displaying the details of a column that contains both PRK & KOR
world_cup.loc[world_cup['Home Team Initials'].isin(['PRK', 'KOR']), 'Home Team Initials'] = "NSK"

# %%
world_cup.loc[world_cup['Home Team Initials'].str.contains('NSK'), 'Home Team Initials']
# Out:
# 179    NSK
# 187    NSK
# 374    NSK
# 386    NSK
# 434    NSK
# 444    NSK
# 480    NSK
# 524    NSK
# 593    NSK
# 609    NSK
# 635    NSK
# 642    NSK
# 655    NSK
# 710    NSK
# 753    NSK
# 802    NSK
# 818    NSK
# Name: Home Team Initials, dtype: object

# %%
world_cup.loc[world_cup['Away Team Initials'].isin(['PRK', 'KOR']), 'Away Team Initials']
# Out:
# 80     KOR
# 88     KOR
# 171    PRK
# 195    PRK
# 364    KOR
# 421    KOR
# 464    KOR
# 490    KOR
# 542    KOR
# 556    KOR
# 625    KOR
# 639    KOR
# 640    KOR
# 672    KOR
# 691    KOR
# 721    PRK
# 725    KOR
# 737    PRK
# 742    KOR
# 756    KOR
# 788    KOR
# Name: Away Team Initials, dtype: object

# %%
world_cup.loc[world_cup['Away Team Initials'].isin(['PRK', 'KOR']), 'Away Team Initials'] = "NSK"

# %%
world_cup.loc[world_cup['Away Team Initials'].str.contains('NSK'), 'Away Team Initials']
# Out:
# 80     NSK
# 88     NSK
# 171    NSK
# 195    NSK
# 364    NSK
# 421    NSK
# 464    NSK
# 490    NSK
# 542    NSK
# 556    NSK
# 625    NSK
# 639    NSK
# 640    NSK
# 672    NSK
# 691    NSK
# 721    NSK
# 725    NSK
# 737    NSK
# 742    NSK
# 756    NSK
# 788    NSK
# Name: Away Team Initials, dtype: object

# %%
world_cup.loc[710:753, 'Home Team Initials':'Away Team Initials']
# Out:
#     Home Team Initials Away Team Initials
# 710                NSK                GRE
# 711                ARG                NGA
# 712                ENG                USA
# 713                ALG                SVN
# 714                SRB                GHA
# 715                GER                AUS
# 716                NED                DEN
# 717                JPN                CMR
# 718                ITA                PAR
# 719                NZL                SVK
# 720                CIV                POR
# 721                BRA                NSK
# 722                HON                CHI
# 723                ESP                SUI
# 724                RSA                URU
# 725                ARG                NSK
# 726                GRE                NGA
# 727                FRA                MEX
# 728                GER                SRB
# 729                SVN                USA
# 730                ENG                ALG
# ...
